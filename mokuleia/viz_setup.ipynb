# %% [markdown]
# #### Computing Setup

# %%
from loadPressureData import loadPressureData
from pathlib import Path
from BulkWaveStats import detide, Spp_to_Seta, sig_wave_height
from detide import detide_df
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from loadPressureData import loadPressureData
#       2 from pathlib import Path
#       3 from BulkWaveStats import detide, Spp_to_Seta, sig_wave_height
#
# ModuleNotFoundError: No module named 'loadPressureData'

# %%
LAT = 21.581
# load .mat file into dataframe 
df1 = loadPressureData(Path("data/MoA18411.mat"))
df4a = loadPressureData(Path("data/MoA48411.mat"))
df4b = loadPressureData(Path("data/MoB48411.mat"))
# detide data
df1 = detide_df(df1, col="pressure_pa", lat=LAT, avg="15min", inplace=False)
df4a = detide_df(df4a, col="pressure_pa", lat=LAT, avg="15min", inplace=False)
df4b = detide_df(df4b, col="pressure_pa", lat=LAT, avg="15min", inplace=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 LAT = 21.581
#       2 # load .mat file into dataframe
# ----> 3 df1 = loadPressureData(Path("data/MoA18411.mat"))
#       4 df4a = loadPressureData(Path("data/MoA48411.mat"))
#       5 df4b = loadPressureData(Path("data/MoB48411.mat"))
#
# NameError: name 'loadPressureData' is not defined
